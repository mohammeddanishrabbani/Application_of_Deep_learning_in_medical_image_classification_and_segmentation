# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import layers
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
def initiateGenerator(path):
    base_path = path
    print("\nTotal : ", end=" ")
    train_dataset = tf.keras.preprocessing.image_dataset_from_directory(batch_size=32, directory=base_path+"/"+"train")

    train_datagen = ImageDataGenerator()

    print("\nFor Training : ", end=" ")
    train_generator = train_datagen.flow_from_directory(
        base_path+"/"+"train",
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical', subset='training')

    print("\nFor Val : ", end=" ")
    valid_datagen = ImageDataGenerator()
    validation_generator = valid_datagen.flow_from_directory(
        base_path+"/"+"val",
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',shuffle=False)
    test_datagen = ImageDataGenerator()
    test_generator = test_datagen.flow_from_directory(
        base_path+"/"+"test",
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical', shuffle=False)
    class_names = train_dataset.class_names
    noOfClasses = len(class_names)
    print("\nNo of Classes : ", noOfClasses)
    print("Classes : ", class_names)

    plt.figure(figsize=(10, 10))
    for images, labels in train_dataset.take(1):
        for i in range(noOfClasses):
            ax = plt.subplot(4, 4, i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))
            plt.title(class_names[labels[i]])
            plt.axis("off")

    for image_batch, labels_batch in train_dataset:
        print("Image Shape : ",image_batch.shape)
        break
        
    return noOfClasses,class_names, train_generator, validation_generator,test_generator

# %%
def initiateNormalize():
    AUTOTUNE = tf.data.AUTOTUNE

    train_ds = train_generator.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
    val_ds = val_generator.cache().prefetch(buffer_size=AUTOTUNE)
    normalization_layer = layers.Rescaling(1./255)

    normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
    image_batch, labels_batch = next(iter(normalized_ds))
    first_image = image_batch[0]
    print(np.min(first_image), np.max(first_image))

# %%
def initiateVGG19(noOfClasses):
    modelInput = tf.keras.applications.VGG19(
        input_shape=IMAGE_SIZE + [3],
        include_top=False,
        weights="imagenet"
    )
    
    for layer in modelInput.layers:
        layer.trainable = False
    
    x = Flatten()(modelInput.output)
    prediction = Dense(noOfClasses, activation='softmax')(x)

    model = Model(inputs=modelInput.input, outputs=prediction)
    return model

def modelSummary(model):
    model.summary()

# %%
def initiateDenseNet201(noOfClasses):
    modelInput = tf.keras.applications.DenseNet201(
        input_shape=IMAGE_SIZE + [3],
        include_top=False,
        weights="imagenet"
    )
    
    for layer in modelInput.layers:
        layer.trainable = False
    
    x = Flatten()(modelInput.output)
    prediction = Dense(noOfClasses, activation='softmax')(x)

    model = Model(inputs=modelInput.input, outputs=prediction)
    return model

# %%
def initiateMobileNetV3(noOfClasses):
    modelInput = tf.keras.applications.MobileNetV3Small(
        input_shape=IMAGE_SIZE + [3],
        include_top=False,
        weights="imagenet"
    )
    
    for layer in modelInput.layers:
        layer.trainable = False
    
    x = Flatten()(modelInput.output)
    prediction = Dense(noOfClasses, activation='softmax')(x)

    model = Model(inputs=modelInput.input, outputs=prediction)
    return model

# %%
def initiateParams(className, model, lr,model_name):
    opt = tf.keras.optimizers.Adam(learning_rate=lr)

    model.compile(optimizer=opt,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
    checkpoint = ModelCheckpoint(className + model_name+'.h5', verbose=1, save_best_only=True)
    
    return model, annealer, checkpoint

# %%
def modelFit(model, annealer, checkpoint, epochs=20, batchSize = 256):

    history = model.fit(
      train_generator,
      validation_data=validation_generator,
      epochs=epochs,
      batch_size=batchSize,
      callbacks=[annealer, checkpoint],
      steps_per_epoch=len(train_generator),
      validation_steps=len(validation_generator)
    )
    
    return history

# %%
def plotOutput(history, className, epochs):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(12, 12))
    plt.subplot(3, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(3, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()
    plt.savefig(className + '_graph.png')

# %%
def evalModel(model):
    evl = model.evaluate(test_generator)
    acc = evl[1]*100
    msg=f'Accuracy on the Test Set = {acc:5.2f} %'
    print(msg)
    return acc
    
def saveModel(model, className,model_name):
    model.save(className + " - "+model_name+"Final.h5")
    print("Model Saved!")

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(15, 15))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    plt.savefig(title + '.png')

# %%
from sklearn.metrics import recall_score,precision_score,f1_score
def callPlot(model, className, classes):
    y_true = test_generator.classes
    print("True : ", (y_true))

    y_pred = model.predict(test_generator)
    y_pred = np.argmax(y_pred, axis=1)
    print("Predicted : ", (y_pred))

    conf_mat = confusion_matrix(y_true, y_pred)
    recall=recall_score(y_true,y_pred,average='weighted')
    p=precision_score(y_true, y_pred,average='weighted')
    f1=f1_score(y_true, y_pred,average='weighted')
    print(f"RECALL={recall}")
    print(f"precision={p}")
    print(f"F1 Score{f1}")
    plot_confusion_matrix(cm           = conf_mat,
                          normalize    = False,
                          target_names = classes,
                          title        = className + "Confusion Matrix")

# %%
mpath = r'../input/multi-cancer/Dataset'
classPaths = os.listdir(mpath)

IMAGE_SIZE = [224, 224]
img_height = 224
img_width = 224
noOfClasses = 0
gEpochs = 10
lr = 0.001

# %%
import pprint
part={}
for c in classPaths:
#     part[c]={'models':{"EfficientNetB7":{"model":None,"accurary":0},
#                     "Densenet201":{"model":None,"accurary":0},
#                     "VGG19":{"model":None,"accurary":0},
#                     "ResnetV2":{"model":None,"accurary":0},
#                     "mobilenetV3":{"model":None,"accurary":0}
#                    },'no_of_classes':0,"ClassNames":None}
    part[c]={'models':{},'no_of_classes':0,"ClassNames":None}

# %%
pprint.pprint(part)
# Out:
# {'ALL': {'ClassNames': None, 'models': {}, 'no_of_classes': 0},
#  'Brain Cancer': {'ClassNames': None, 'models': {}, 'no_of_classes': 0},
#  'Breast Cancer': {'ClassNames': None, 'models': {}, 'no_of_classes': 0},
#  'Cervical Cancer': {'ClassNames': None, 'models': {}, 'no_of_classes': 0},
#  'Kidney Cancer': {'ClassNames': None, 'models': {}, 'no_of_classes': 0},
#  'Lung and Colon Cancer': {'ClassNames': None,
#                            'models': {},
#                            'no_of_classes': 0},
#  'Lymphoma': {'ClassNames': None, 'models': {}, 'no_of_classes': 0},
#  'Oral Cancer': {'ClassNames': None, 'models': {}, 'no_of_classes': 0}}

# %%
def Ensemble(c):
    y_true = test_generator.classes
    print("True : ", (y_true))
    pred=[]
    for model,obj in part[c]['models'].items():
        pred.append(obj['model'].predict(test_generator)*obj['Accurary'])
    y_pred=pred[0]
    for i in range(1,len(pred)):
        y_pred=y_pred+pred[i]
        
    y_pred = np.argmax(y_pred, axis=1)
    print("Predicted : ", (y_pred))

    conf_mat = confusion_matrix(y_true, y_pred)
    recall=recall_score(y_true,y_pred,average='weighted')
    p=precision_score(y_true, y_pred,average='weighted')
    f1=f1_score(y_true, y_pred,average='weighted')
    print(f"RECALL={recall}")
    print(f"precision={p}")
    print(f"F1 Score{f1}")

    plot_confusion_matrix(cm           = conf_mat,
                          normalize    = False,
                          target_names = part[c]['ClassNames'],
                          title        = c + "Confusion Matrix")

# %%
def initiateResNet50V2(noOfClasses):
    modelInput = tf.keras.applications.ResNet50V2(
        input_shape=IMAGE_SIZE + [3],
        include_top=False,
        weights="imagenet"
    )
    
    for layer in modelInput.layers:
        layer.trainable = False
    
    x = Flatten()(modelInput.output)
    prediction = Dense(noOfClasses, activation='softmax')(x)

    model = Model(inputs=modelInput.input, outputs=prediction)
    return model

# %%
for c in classPaths[3:4]:
    className = c
#     model_name="VGG-19"
    cpath = os.path.join(mpath, c)
    noOfClasses, class_names, train_generator, validation_generator,test_generator = initiateGenerator(cpath)
    part[c]['ClassNames']=class_names
    
    
    
    model_name="VGG-19"
    print("######################################################")
    print(f"RESULTS FOR{model_name}")
    curVGG19 = initiateVGG19(noOfClasses)
    #modelSummary(curVGG19)
    curVGG19, annealer, checkpoint = initiateParams(className, curVGG19, lr,model_name)
    curHistory = modelFit(curVGG19, annealer, checkpoint, epochs=gEpochs, batchSize=256)
    plotOutput(curHistory, className, gEpochs)
    acc=evalModel(curVGG19)
    
    saveModel(curVGG19, className,model_name)
    part[c]['models']['VGG19']={"model":curVGG19,'Accurary':acc}
    callPlot(curVGG19, className, class_names)
    
    model_name="DenseNet201"
    print("######################################################")
    print(f"RESULTS FOR{model_name}")
    curDenseNet201= initiateDenseNet201(noOfClasses)
    #modelSummary(curDenseNet201)
    curDenseNet201, annealer, checkpoint = initiateParams(className, curDenseNet201, lr,model_name)
    curHistory = modelFit(curDenseNet201, annealer, checkpoint, epochs=gEpochs, batchSize=256)
    plotOutput(curHistory, className, gEpochs)
    acc=evalModel(curDenseNet201)
    saveModel(curDenseNet201, className,model_name)
    part[c]['models']['DenseNet201']={"model":curDenseNet201,'Accurary':acc}
    callPlot(curDenseNet201, className, class_names)
    
    
    
    model_name="MobileNetV3"
    print("######################################################")
    print(f"RESULTS FOR{model_name}")
    curMobileNetV3 = initiateMobileNetV3(noOfClasses)
    #modelSummary(curMobileNetV3)
    curMobileNetV3, annealer, checkpoint = initiateParams(className, curMobileNetV3, lr,model_name)
    curHistory = modelFit(curMobileNetV3, annealer, checkpoint, epochs=gEpochs, batchSize=256)
    plotOutput(curHistory, className, gEpochs)
    acc=evalModel(curMobileNetV3)
    saveModel(curMobileNetV3, className,model_name)
    part[c]['models']['MobileNetV3']={"model":curMobileNetV3,'Accurary':acc}
    callPlot(curMobileNetV3, className, class_names)
    
    model_name="ResNet50V2"
    print("######################################################")
    print(f"RESULTS FOR{model_name}")
    curResNet50V2 = initiateResNet50V2(noOfClasses)
    #modelSummary(curResNet50V2)
    curResNet50V2, annealer, checkpoint = initiateParams(className, curResNet50V2, lr,model_name)
    curHistory = modelFit(curResNet50V2, annealer, checkpoint, epochs=gEpochs, batchSize=256)
    plotOutput(curHistory, className, gEpochs)
    acc=evalModel(curResNet50V2)
    saveModel(curResNet50V2, className,model_name)
    part[c]['models']['ResNet50V2']={"model":curResNet50V2,'Accurary':acc}
    callPlot(curResNet50V2, className, class_names)
    print("######################################################")
    print(f"RESULTS FOR ENSEMBLE")
    Ensemble(c)
# Out:
# Total :  Found 14000 files belonging to 4 classes.
#
# For Training :  Found 14000 images belonging to 4 classes.
#
# For Val :  Found 3000 images belonging to 4 classes.
# Found 3000 images belonging to 4 classes.
#
# No of Classes :  4
# Classes :  ['all_benign', 'all_early', 'all_pre', 'all_pro']
# Image Shape :  (32, 256, 256, 3)
# ######################################################
# RESULTS FORVGG-19
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# Epoch 1/10
# 438/438 [==============================] - ETA: 0s - loss: 1.3964 - accuracy: 0.9377
# Epoch 1: val_loss improved from inf to 0.34977, saving model to ALLVGG-19.h5
# 438/438 [==============================] - 177s 384ms/step - loss: 1.3964 - accuracy: 0.9377 - val_loss: 0.3498 - val_accuracy: 0.9777 - lr: 0.0010
# Epoch 2/10
# 438/438 [==============================] - ETA: 0s - loss: 0.2704 - accuracy: 0.9852
# Epoch 2: val_loss did not improve from 0.34977
# 438/438 [==============================] - 56s 127ms/step - loss: 0.2704 - accuracy: 0.9852 - val_loss: 0.5141 - val_accuracy: 0.9777 - lr: 0.0010
# Epoch 3/10
# 438/438 [==============================] - ETA: 0s - loss: 0.1999 - accuracy: 0.9906
# Epoch 3: val_loss did not improve from 0.34977
# 438/438 [==============================] - 56s 128ms/step - loss: 0.1999 - accuracy: 0.9906 - val_loss: 0.8594 - val_accuracy: 0.9723 - lr: 0.0010
# Epoch 4/10
# 438/438 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9921
# Epoch 4: val_loss did not improve from 0.34977
# 438/438 [==============================] - 56s 128ms/step - loss: 0.1986 - accuracy: 0.9921 - val_loss: 0.9972 - val_accuracy: 0.9770 - lr: 0.0010
# Epoch 5/10
# 438/438 [==============================] - ETA: 0s - loss: 0.1315 - accuracy: 0.9945
# Epoch 5: val_loss did not improve from 0.34977
# 438/438 [==============================] - 57s 131ms/step - loss: 0.1315 - accuracy: 0.9945 - val_loss: 0.3820 - val_accuracy: 0.9900 - lr: 0.0010
# Epoch 6/10
# 438/438 [==============================] - ETA: 0s - loss: 0.2797 - accuracy: 0.9908
# Epoch 6: val_loss did not improve from 0.34977
# 438/438 [==============================] - 57s 129ms/step - loss: 0.2797 - accuracy: 0.9908 - val_loss: 0.5545 - val_accuracy: 0.9873 - lr: 0.0010
# Epoch 7/10
# 438/438 [==============================] - ETA: 0s - loss: 0.0890 - accuracy: 0.9964
# Epoch 7: val_loss did not improve from 0.34977
# 438/438 [==============================] - 59s 134ms/step - loss: 0.0890 - accuracy: 0.9964 - val_loss: 0.4456 - val_accuracy: 0.9867 - lr: 0.0010
# Epoch 8/10
# 438/438 [==============================] - ETA: 0s - loss: 0.0963 - accuracy: 0.9966
# Epoch 8: val_loss did not improve from 0.34977
# 438/438 [==============================] - 57s 129ms/step - loss: 0.0963 - accuracy: 0.9966 - val_loss: 0.3790 - val_accuracy: 0.9880 - lr: 0.0010
# Epoch 9/10
# 438/438 [==============================] - ETA: 0s - loss: 0.2384 - accuracy: 0.9936
# Epoch 9: val_loss did not improve from 0.34977
# 438/438 [==============================] - 57s 131ms/step - loss: 0.2384 - accuracy: 0.9936 - val_loss: 0.6076 - val_accuracy: 0.9857 - lr: 0.0010
# Epoch 10/10
# 438/438 [==============================] - ETA: 0s - loss: 0.1123 - accuracy: 0.9965
# Epoch 10: val_loss did not improve from 0.34977
# 438/438 [==============================] - 57s 129ms/step - loss: 0.1123 - accuracy: 0.9965 - val_loss: 0.4504 - val_accuracy: 0.9910 - lr: 0.0010
# 94/94 [==============================] - 35s 373ms/step - loss: 0.5604 - accuracy: 0.9913
# Accuracy on the Test Set = 99.13 %
# Model Saved!
# True :  [0 0 0 ... 3 3 3]
# 94/94 [==============================] - 10s 107ms/step
# Predicted :  [0 0 0 ... 3 3 3]
# RECALL=0.9913333333333333
# precision=0.9913810676610213
# F1 Score0.99133643551295
# ######################################################
# RESULTS FORDenseNet201
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 0s 0us/step
# Epoch 1/10
# 438/438 [==============================] - ETA: 0s - loss: 3.5131 - accuracy: 0.9130
# Epoch 1: val_loss improved from inf to 0.30491, saving model to ALLDenseNet201.h5
# 438/438 [==============================] - 81s 155ms/step - loss: 3.5131 - accuracy: 0.9130 - val_loss: 0.3049 - val_accuracy: 0.9807 - lr: 0.0010
# Epoch 2/10
# 438/438 [==============================] - ETA: 0s - loss: 0.6046 - accuracy: 0.9714
# Epoch 2: val_loss did not improve from 0.30491
# 438/438 [==============================] - 57s 130ms/step - loss: 0.6046 - accuracy: 0.9714 - val_loss: 0.4824 - val_accuracy: 0.9773 - lr: 0.0010
# Epoch 3/10
# 438/438 [==============================] - ETA: 0s - loss: 0.2598 - accuracy: 0.9872
# Epoch 3: val_loss improved from 0.30491 to 0.19417, saving model to ALLDenseNet201.h5
# 438/438 [==============================] - 59s 135ms/step - loss: 0.2598 - accuracy: 0.9872 - val_loss: 0.1942 - val_accuracy: 0.9927 - lr: 0.0010
# Epoch 4/10
# 438/438 [==============================] - ETA: 0s - loss: 0.4503 - accuracy: 0.9834
# Epoch 4: val_loss did not improve from 0.19417
# 438/438 [==============================] - 59s 135ms/step - loss: 0.4503 - accuracy: 0.9834 - val_loss: 0.4658 - val_accuracy: 0.9830 - lr: 0.0010
# Epoch 5/10
# 438/438 [==============================] - ETA: 0s - loss: 0.3077 - accuracy: 0.9890
# Epoch 5: val_loss did not improve from 0.19417
# 438/438 [==============================] - 58s 133ms/step - loss: 0.3077 - accuracy: 0.9890 - val_loss: 1.5607 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 6/10
# 438/438 [==============================] - ETA: 0s - loss: 0.4124 - accuracy: 0.9886
# Epoch 6: val_loss did not improve from 0.19417
# 438/438 [==============================] - 57s 131ms/step - loss: 0.4124 - accuracy: 0.9886 - val_loss: 0.3412 - val_accuracy: 0.9913 - lr: 0.0010
# Epoch 7/10
# 438/438 [==============================] - ETA: 0s - loss: 0.3867 - accuracy: 0.9895
# Epoch 7: val_loss did not improve from 0.19417
# 438/438 [==============================] - 57s 131ms/step - loss: 0.3867 - accuracy: 0.9895 - val_loss: 0.2246 - val_accuracy: 0.9927 - lr: 0.0010
# Epoch 8/10
# 438/438 [==============================] - ETA: 0s - loss: 0.2753 - accuracy: 0.9923
# Epoch 8: val_loss did not improve from 0.19417
# 438/438 [==============================] - 59s 135ms/step - loss: 0.2753 - accuracy: 0.9923 - val_loss: 1.3602 - val_accuracy: 0.9700 - lr: 0.0010
# Epoch 9/10
# 438/438 [==============================] - ETA: 0s - loss: 0.3436 - accuracy: 0.9919
# Epoch 9: val_loss did not improve from 0.19417
# 438/438 [==============================] - 57s 130ms/step - loss: 0.3436 - accuracy: 0.9919 - val_loss: 0.5403 - val_accuracy: 0.9873 - lr: 0.0010
# Epoch 10/10
# 438/438 [==============================] - ETA: 0s - loss: 0.2678 - accuracy: 0.9932
# Epoch 10: val_loss did not improve from 0.19417
# 438/438 [==============================] - 57s 130ms/step - loss: 0.2678 - accuracy: 0.9932 - val_loss: 0.4451 - val_accuracy: 0.9933 - lr: 0.0010
# 94/94 [==============================] - 13s 137ms/step - loss: 0.7154 - accuracy: 0.9903
# Accuracy on the Test Set = 99.03 %
# Model Saved!
# True :  [0 0 0 ... 3 3 3]
# 94/94 [==============================] - 13s 105ms/step
# Predicted :  [0 0 0 ... 3 3 3]
# RECALL=0.9903333333333333
# precision=0.9904421811723344
# F1 Score0.9903241375685572
# ######################################################
# RESULTS FORMobileNetV3
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top_v2.h5
# 4334752/4334752 [==============================] - 0s 0us/step
# Epoch 1/10
# 438/438 [==============================] - ETA: 0s - loss: 0.3032 - accuracy: 0.9407
# Epoch 1: val_loss improved from inf to 0.06442, saving model to ALLMobileNetV3.h5
# 438/438 [==============================] - 55s 117ms/step - loss: 0.3032 - accuracy: 0.9407 - val_loss: 0.0644 - val_accuracy: 0.9853 - lr: 0.0010
# Epoch 2/10
# 438/438 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9892
# Epoch 2: val_loss did not improve from 0.06442
# 438/438 [==============================] - 50s 113ms/step - loss: 0.0406 - accuracy: 0.9892 - val_loss: 0.0932 - val_accuracy: 0.9820 - lr: 0.0010
# Epoch 3/10
# 438/438 [==============================] - ETA: 0s - loss: 0.0430 - accuracy: 0.9906
# Epoch 3: val_loss did not improve from 0.06442
# 438/438 [==============================] - 49s 111ms/step - loss: 0.0430 - accuracy: 0.9906 - val_loss: 0.0934 - val_accuracy: 0.9857 - lr: 0.0010
# Epoch 4/10
# 438/438 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9913
# Epoch 4: val_loss did not improve from 0.06442
# 438/438 [==============================] - 51s 116ms/step - loss: 0.0542 - accuracy: 0.9913 - val_loss: 0.2001 - val_accuracy: 0.9740 - lr: 0.0010
# Epoch 5/10
# 438/438 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.9949
# Epoch 5: val_loss did not improve from 0.06442
# 438/438 [==============================] - 52s 120ms/step - loss: 0.0306 - accuracy: 0.9949 - val_loss: 0.1227 - val_accuracy: 0.9823 - lr: 0.0010
# Epoch 6/10
# 438/438 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9940
# Epoch 6: val_loss did not improve from 0.06442
# 438/438 [==============================] - 55s 126ms/step - loss: 0.0405 - accuracy: 0.9940 - val_loss: 0.1130 - val_accuracy: 0.9847 - lr: 0.0010
# Epoch 7/10
# 438/438 [==============================] - ETA: 0s - loss: 0.0441 - accuracy: 0.9947
# Epoch 7: val_loss did not improve from 0.06442
# 438/438 [==============================] - 48s 109ms/step - loss: 0.0441 - accuracy: 0.9947 - val_loss: 0.1382 - val_accuracy: 0.9853 - lr: 0.0010
# Epoch 8/10
# 438/438 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9971
# Epoch 8: val_loss improved from 0.06442 to 0.06431, saving model to ALLMobileNetV3.h5
# 438/438 [==============================] - 49s 112ms/step - loss: 0.0185 - accuracy: 0.9971 - val_loss: 0.0643 - val_accuracy: 0.9927 - lr: 0.0010
# Epoch 9/10
# 438/438 [==============================] - ETA: 0s - loss: 0.0459 - accuracy: 0.9944
# Epoch 9: val_loss did not improve from 0.06431
# 438/438 [==============================] - 52s 118ms/step - loss: 0.0459 - accuracy: 0.9944 - val_loss: 0.4527 - val_accuracy: 0.9727 - lr: 0.0010
# Epoch 10/10
# 438/438 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9970
# Epoch 10: val_loss did not improve from 0.06431
# 438/438 [==============================] - 51s 116ms/step - loss: 0.0199 - accuracy: 0.9970 - val_loss: 0.1160 - val_accuracy: 0.9910 - lr: 0.0010
# 94/94 [==============================] - 9s 97ms/step - loss: 0.1211 - accuracy: 0.9917
# Accuracy on the Test Set = 99.17 %
# Model Saved!
# True :  [0 0 0 ... 3 3 3]
# 94/94 [==============================] - 9s 90ms/step
# Predicted :  [0 0 0 ... 3 3 3]
# RECALL=0.9916666666666667
# precision=0.991678857124651
# F1 Score0.9916619096443816
# ######################################################
# RESULTS FORResNet50V2
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 0s 0us/step
# Epoch 1/10
# 438/438 [==============================] - ETA: 0s - loss: 271.2363 - accuracy: 0.6162
# Epoch 1: val_loss improved from inf to 69.16250, saving model to ALLResNet50V2.h5
# 438/438 [==============================] - 61s 129ms/step - loss: 271.2363 - accuracy: 0.6162 - val_loss: 69.1625 - val_accuracy: 0.7737 - lr: 0.0010
# Epoch 2/10
# 438/438 [==============================] - ETA: 0s - loss: 104.6838 - accuracy: 0.7354
# Epoch 2: val_loss improved from 69.16250 to 49.31223, saving model to ALLResNet50V2.h5
# 438/438 [==============================] - 54s 124ms/step - loss: 104.6838 - accuracy: 0.7354 - val_loss: 49.3122 - val_accuracy: 0.8327 - lr: 0.0010
# Epoch 3/10
# 438/438 [==============================] - ETA: 0s - loss: 86.0533 - accuracy: 0.7824
# Epoch 3: val_loss did not improve from 49.31223
# 438/438 [==============================] - 55s 124ms/step - loss: 86.0533 - accuracy: 0.7824 - val_loss: 118.8282 - val_accuracy: 0.7510 - lr: 0.0010
# Epoch 4/10
# 438/438 [==============================] - ETA: 0s - loss: 85.7308 - accuracy: 0.8104
# Epoch 4: val_loss improved from 49.31223 to 44.54833, saving model to ALLResNet50V2.h5
# 438/438 [==============================] - 54s 124ms/step - loss: 85.7308 - accuracy: 0.8104 - val_loss: 44.5483 - val_accuracy: 0.8473 - lr: 0.0010
# Epoch 5/10
# 438/438 [==============================] - ETA: 0s - loss: 74.3973 - accuracy: 0.8318
# Epoch 5: val_loss improved from 44.54833 to 32.32495, saving model to ALLResNet50V2.h5
# 438/438 [==============================] - 52s 118ms/step - loss: 74.3973 - accuracy: 0.8318 - val_loss: 32.3250 - val_accuracy: 0.8893 - lr: 0.0010
# Epoch 6/10
# 438/438 [==============================] - ETA: 0s - loss: 78.3995 - accuracy: 0.8332
# Epoch 6: val_loss did not improve from 32.32495
# 438/438 [==============================] - 53s 121ms/step - loss: 78.3995 - accuracy: 0.8332 - val_loss: 127.8546 - val_accuracy: 0.7800 - lr: 0.0010
# Epoch 7/10
# 438/438 [==============================] - ETA: 0s - loss: 116.2238 - accuracy: 0.8127
# Epoch 7: val_loss did not improve from 32.32495
# 438/438 [==============================] - 53s 121ms/step - loss: 116.2238 - accuracy: 0.8127 - val_loss: 164.8919 - val_accuracy: 0.7420 - lr: 0.0010
# Epoch 8/10
# 438/438 [==============================] - ETA: 0s - loss: 63.9024 - accuracy: 0.8676
# Epoch 8: val_loss did not improve from 32.32495
# 438/438 [==============================] - 52s 119ms/step - loss: 63.9024 - accuracy: 0.8676 - val_loss: 60.6236 - val_accuracy: 0.8537 - lr: 0.0010
# Epoch 9/10
# 438/438 [==============================] - ETA: 0s - loss: 69.5966 - accuracy: 0.8704
# Epoch 9: val_loss did not improve from 32.32495
# 438/438 [==============================] - 52s 118ms/step - loss: 69.5966 - accuracy: 0.8704 - val_loss: 53.1740 - val_accuracy: 0.8927 - lr: 0.0010
# Epoch 10/10
# 438/438 [==============================] - ETA: 0s - loss: 82.3340 - accuracy: 0.8636
# Epoch 10: val_loss did not improve from 32.32495
# 438/438 [==============================] - 55s 125ms/step - loss: 82.3340 - accuracy: 0.8636 - val_loss: 144.9902 - val_accuracy: 0.8023 - lr: 0.0010
# 94/94 [==============================] - 10s 101ms/step - loss: 139.9314 - accuracy: 0.7963
# Accuracy on the Test Set = 79.63 %
# Model Saved!
# True :  [0 0 0 ... 3 3 3]
# 94/94 [==============================] - 10s 98ms/step
# Predicted :  [0 1 0 ... 3 3 1]
# RECALL=0.7963333333333333
# precision=0.8631494378615919
# F1 Score0.7981504464349779
# ######################################################
# RESULTS FOR ENSEMBLE
# True :  [0 0 0 ... 3 3 3]
# 94/94 [==============================] - 10s 108ms/step
# 94/94 [==============================] - 10s 106ms/step
# 94/94 [==============================] - 9s 97ms/step
# 94/94 [==============================] - 10s 101ms/step
# Predicted :  [0 0 0 ... 3 3 3]
# RECALL=0.998
# precision=0.998006178550939
# F1 Score0.9979997690422237
