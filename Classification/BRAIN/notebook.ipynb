# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import layers

# %%
def initiateGenerator(path):
    base_path = path
    print("\nTotal : ", end=" ")
    train_dataset = tf.keras.preprocessing.image_dataset_from_directory(batch_size=32, directory=base_path+"/"+"train")

    train_datagen = ImageDataGenerator()

    print("\nFor Training : ", end=" ")
    train_generator = train_datagen.flow_from_directory(
        base_path+"/"+"train",
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical', subset='training')

    print("\nFor Val : ", end=" ")
    valid_datagen = ImageDataGenerator()
    validation_generator = valid_datagen.flow_from_directory(
        base_path+"/"+"val",
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',shuffle=False)
    test_datagen = ImageDataGenerator()
    test_generator = test_datagen.flow_from_directory(
        base_path+"/"+"test",
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical', shuffle=False)
    class_names = train_dataset.class_names
    noOfClasses = len(class_names)
    print("\nNo of Classes : ", noOfClasses)
    print("Classes : ", class_names)

    plt.figure(figsize=(10, 10))
    for images, labels in train_dataset.take(1):
        for i in range(noOfClasses):
            ax = plt.subplot(4, 4, i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))
            plt.title(class_names[labels[i]])
            plt.axis("off")

    for image_batch, labels_batch in train_dataset:
        print("Image Shape : ",image_batch.shape)
        break
        
    return noOfClasses,class_names, train_generator, validation_generator,test_generator

# %%
def initiateNormalize():
    AUTOTUNE = tf.data.AUTOTUNE

    train_ds = train_generator.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
    val_ds = val_generator.cache().prefetch(buffer_size=AUTOTUNE)
    normalization_layer = layers.Rescaling(1./255)

    normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
    image_batch, labels_batch = next(iter(normalized_ds))
    first_image = image_batch[0]
    print(np.min(first_image), np.max(first_image))

# %%
def initiateVGG19(noOfClasses):
    modelInput = tf.keras.applications.VGG19(
        input_shape=IMAGE_SIZE + [3],
        include_top=False,
        weights="imagenet"
    )
    
    for layer in modelInput.layers:
        layer.trainable = False
    
    x = Flatten()(modelInput.output)
    prediction = Dense(noOfClasses, activation='softmax')(x)

    model = Model(inputs=modelInput.input, outputs=prediction)
    return model

def modelSummary(model):
    model.summary()

# %%
def initiateDenseNet201(noOfClasses):
    modelInput = tf.keras.applications.DenseNet201(
        input_shape=IMAGE_SIZE + [3],
        include_top=False,
        weights="imagenet"
    )
    
    for layer in modelInput.layers:
        layer.trainable = False
    
    x = Flatten()(modelInput.output)
    prediction = Dense(noOfClasses, activation='softmax')(x)

    model = Model(inputs=modelInput.input, outputs=prediction)
    return model

# %%
def initiateMobileNetV3(noOfClasses):
    modelInput = tf.keras.applications.MobileNetV3Small(
        input_shape=IMAGE_SIZE + [3],
        include_top=False,
        weights="imagenet"
    )
    
    for layer in modelInput.layers:
        layer.trainable = False
    
    x = Flatten()(modelInput.output)
    prediction = Dense(noOfClasses, activation='softmax')(x)

    model = Model(inputs=modelInput.input, outputs=prediction)
    return model

# %%
def initiateParams(className, model, lr,model_name):
    opt = tf.keras.optimizers.Adam(learning_rate=lr)

    model.compile(optimizer=opt,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
    checkpoint = ModelCheckpoint(className + model_name+'.h5', verbose=1, save_best_only=True)
    
    return model, annealer, checkpoint

# %%
def modelFit(model, annealer, checkpoint, epochs=20, batchSize = 256):

    history = model.fit(
      train_generator,
      validation_data=validation_generator,
      epochs=epochs,
      batch_size=batchSize,
      callbacks=[annealer, checkpoint],
      steps_per_epoch=len(train_generator),
      validation_steps=len(validation_generator)
    )
    
    return history

# %%
def plotOutput(history, className, epochs):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(12, 12))
    plt.subplot(3, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(3, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()
    plt.savefig(className + '_graph.png')

# %%
def evalModel(model):
    evl = model.evaluate(test_generator)
    acc = evl[1]*100
    msg=f'Accuracy on the Test Set = {acc:5.2f} %'
    print(msg)
    return acc
    
def saveModel(model, className,model_name):
    model.save(className + " - "+model_name+"Final.h5")
    print("Model Saved!")

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(15, 15))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    plt.savefig(title + '.png')

# %%
from sklearn.metrics import recall_score,precision_score,f1_score
def callPlot(model, className, classes):
    y_true = test_generator.classes
    print("True : ", (y_true))

    y_pred = model.predict(test_generator)
    y_pred = np.argmax(y_pred, axis=1)
    print("Predicted : ", (y_pred))
    
    conf_mat = confusion_matrix(y_true, y_pred)
    acc=np.trace(conf_mat) / float(np.sum(conf_mat))
    print(f"ACCURACY={acc}")
    recall=recall_score(y_true,y_pred,average='weighted')
    p=precision_score(y_true, y_pred,average='weighted')
    f1=f1_score(y_true, y_pred,average='weighted')
   
    print(f"RECALL={recall}")
    print(f"precision={p}")
    print(f"F1 Score{f1}")
    plot_confusion_matrix(cm           = conf_mat,
                          normalize    = False,
                          target_names = classes,
                          title        = className + "Confusion Matrix")

# %%
mpath = r'../input/multi-cancer/Dataset'
classPaths = os.listdir(mpath)

IMAGE_SIZE = [224, 224]
img_height = 224
img_width = 224
noOfClasses = 0
gEpochs = 30
lr = 0.002

# %%
import pprint
part={}
for c in classPaths:
#     part[c]={'models':{"EfficientNetB7":{"model":None,"accurary":0},
#                     "Densenet201":{"model":None,"accurary":0},
#                     "VGG19":{"model":None,"accurary":0},
#                     "ResnetV2":{"model":None,"accurary":0},
#                     "mobilenetV3":{"model":None,"accurary":0}
#                    },'no_of_classes':0,"ClassNames":None}
    part[c]={'models':{},'no_of_classes':0,"ClassNames":None}

# %%
pprint.pprint(part)
# Out:
# {'ALL': {'ClassNames': None, 'models': {}, 'no_of_classes': 0},
#  'Brain Cancer': {'ClassNames': None, 'models': {}, 'no_of_classes': 0},
#  'Breast Cancer': {'ClassNames': None, 'models': {}, 'no_of_classes': 0},
#  'Cervical Cancer': {'ClassNames': None, 'models': {}, 'no_of_classes': 0},
#  'Kidney Cancer': {'ClassNames': None, 'models': {}, 'no_of_classes': 0},
#  'Lung and Colon Cancer': {'ClassNames': None,
#                            'models': {},
#                            'no_of_classes': 0},
#  'Lymphoma': {'ClassNames': None, 'models': {}, 'no_of_classes': 0},
#  'Oral Cancer': {'ClassNames': None, 'models': {}, 'no_of_classes': 0}}

# %%
def Ensemble(c):
    y_true = test_generator.classes
    print("True : ", (y_true))
    pred=[]
    for model,obj in part[c]['models'].items():
        pred.append(obj['model'].predict(test_generator)*obj['Accurary'])
    y_pred=pred[0]
    for i in range(1,len(pred)):
        y_pred=y_pred+pred[i]
        
    y_pred = np.argmax(y_pred, axis=1)
    print("Predicted : ", (y_pred))

    conf_mat = confusion_matrix(y_true, y_pred)
    acc=np.trace(conf_mat) / float(np.sum(conf_mat))
    print(f"ACCURACY={acc}")
    recall=recall_score(y_true,y_pred,average='weighted')
    p=precision_score(y_true, y_pred,average='weighted')
    f1=f1_score(y_true, y_pred,average='weighted')
    print(f"RECALL={recall}")
    print(f"precision={p}")
    print(f"F1 Score{f1}")

    plot_confusion_matrix(cm           = conf_mat,
                          normalize    = False,
                          target_names = part[c]['ClassNames'],
                          title        = c + "Confusion Matrix")

# %%
def initiateResNet50V2(noOfClasses):
    modelInput = tf.keras.applications.ResNet50V2(
        input_shape=IMAGE_SIZE + [3],
        include_top=False,
        weights="imagenet"
    )
    
    for layer in modelInput.layers:
        layer.trainable = False
    
    x = Flatten()(modelInput.output)
    prediction = Dense(noOfClasses, activation='softmax')(x)

    model = Model(inputs=modelInput.input, outputs=prediction)
    return model

# %%
for c in classPaths:
    print(c)
# Out:
# Cervical Cancer
# Lung and Colon Cancer
# Oral Cancer
# ALL
# Kidney Cancer
# Breast Cancer
# Lymphoma
# Brain Cancer

# %%
for c in classPaths[7:8]:
    className = c
#     model_name="VGG-19"
    cpath = os.path.join(mpath, c)
    noOfClasses, class_names, train_generator, validation_generator,test_generator = initiateGenerator(cpath)
    part[c]['ClassNames']=class_names
    
    
    
    model_name="VGG-19"
    print("######################################################")
    print(f"RESULTS FOR{model_name}")
    curVGG19 = initiateVGG19(noOfClasses)
    #modelSummary(curVGG19)
    curVGG19, annealer, checkpoint = initiateParams(className, curVGG19, lr,model_name)
    curHistory = modelFit(curVGG19, annealer, checkpoint, epochs=gEpochs, batchSize=256)
    plotOutput(curHistory, className, gEpochs)
    acc=evalModel(curVGG19)
    
    saveModel(curVGG19, className,model_name)
    part[c]['models']['VGG19']={"model":curVGG19,'Accurary':acc}
    callPlot(curVGG19, className, class_names)
    
    model_name="DenseNet201"
    print("######################################################")
    print(f"RESULTS FOR{model_name}")
    curDenseNet201= initiateDenseNet201(noOfClasses)
    #modelSummary(curDenseNet201)
    curDenseNet201, annealer, checkpoint = initiateParams(className, curDenseNet201, lr,model_name)
    curHistory = modelFit(curDenseNet201, annealer, checkpoint, epochs=gEpochs, batchSize=256)
    plotOutput(curHistory, className, gEpochs)
    acc=evalModel(curDenseNet201)
    saveModel(curDenseNet201, className,model_name)
    part[c]['models']['DenseNet201']={"model":curDenseNet201,'Accurary':acc}
    callPlot(curDenseNet201, className, class_names)
    
    
    
    model_name="MobileNetV3"
    print("######################################################")
    print(f"RESULTS FOR{model_name}")
    curMobileNetV3 = initiateMobileNetV3(noOfClasses)
    #modelSummary(curMobileNetV3)
    curMobileNetV3, annealer, checkpoint = initiateParams(className, curMobileNetV3, lr,model_name)
    curHistory = modelFit(curMobileNetV3, annealer, checkpoint, epochs=gEpochs, batchSize=256)
    plotOutput(curHistory, className, gEpochs)
    acc=evalModel(curMobileNetV3)
    saveModel(curMobileNetV3, className,model_name)
    part[c]['models']['MobileNetV3']={"model":curMobileNetV3,'Accurary':acc}
    callPlot(curMobileNetV3, className, class_names)
    
    model_name="ResNet50V2"
    print("######################################################")
    print(f"RESULTS FOR{model_name}")
    curResNet50V2 = initiateResNet50V2(noOfClasses)
    #modelSummary(curResNet50V2)
    curResNet50V2, annealer, checkpoint = initiateParams(className, curResNet50V2, lr,model_name)
    curHistory = modelFit(curResNet50V2, annealer, checkpoint, epochs=gEpochs, batchSize=256)
    plotOutput(curHistory, className, gEpochs)
    acc=evalModel(curResNet50V2)
    saveModel(curResNet50V2, className,model_name)
    part[c]['models']['ResNet50V2']={"model":curResNet50V2,'Accurary':acc}
    callPlot(curResNet50V2, className, class_names)
    print("######################################################")
    print(f"RESULTS FOR ENSEMBLE")
    Ensemble(c)
# Out:
# Total :  Found 10500 files belonging to 3 classes.
#
# For Training :  Found 10500 images belonging to 3 classes.
#
# For Val :  Found 2250 images belonging to 3 classes.
# Found 2250 images belonging to 3 classes.
#
# No of Classes :  3
# Classes :  ['brain_glioma', 'brain_menin', 'brain_tumor']
# Image Shape :  (32, 256, 256, 3)
# ######################################################
# RESULTS FORVGG-19
# Epoch 1/30
# 329/329 [==============================] - ETA: 0s - loss: 4.0318 - accuracy: 0.8810
# Epoch 1: val_loss improved from inf to 1.66633, saving model to Brain CancerVGG-19.h5
# 329/329 [==============================] - 40s 120ms/step - loss: 4.0318 - accuracy: 0.8810 - val_loss: 1.6663 - val_accuracy: 0.9440 - lr: 0.0020
# Epoch 2/30
# 329/329 [==============================] - ETA: 0s - loss: 1.3264 - accuracy: 0.9582
# Epoch 2: val_loss improved from 1.66633 to 1.50389, saving model to Brain CancerVGG-19.h5
# 329/329 [==============================] - 43s 129ms/step - loss: 1.3264 - accuracy: 0.9582 - val_loss: 1.5039 - val_accuracy: 0.9551 - lr: 0.0020
# Epoch 3/30
# 329/329 [==============================] - ETA: 0s - loss: 1.0962 - accuracy: 0.9684
# Epoch 3: val_loss did not improve from 1.50389
# 329/329 [==============================] - 41s 124ms/step - loss: 1.0962 - accuracy: 0.9684 - val_loss: 1.6009 - val_accuracy: 0.9631 - lr: 0.0020
# Epoch 4/30
# 329/329 [==============================] - ETA: 0s - loss: 0.7437 - accuracy: 0.9776
# Epoch 4: val_loss did not improve from 1.50389
# 329/329 [==============================] - 42s 127ms/step - loss: 0.7437 - accuracy: 0.9776 - val_loss: 2.0068 - val_accuracy: 0.9564 - lr: 0.0020
# Epoch 5/30
# 329/329 [==============================] - ETA: 0s - loss: 0.6103 - accuracy: 0.9820
# Epoch 5: val_loss did not improve from 1.50389
# 329/329 [==============================] - 41s 126ms/step - loss: 0.6103 - accuracy: 0.9820 - val_loss: 1.7233 - val_accuracy: 0.9613 - lr: 0.0020
# Epoch 6/30
# 329/329 [==============================] - ETA: 0s - loss: 0.6019 - accuracy: 0.9823
# Epoch 6: val_loss did not improve from 1.50389
# 329/329 [==============================] - 41s 125ms/step - loss: 0.6019 - accuracy: 0.9823 - val_loss: 2.2109 - val_accuracy: 0.9627 - lr: 0.0020
# Epoch 7/30
# 329/329 [==============================] - ETA: 0s - loss: 0.5131 - accuracy: 0.9861
# Epoch 7: val_loss did not improve from 1.50389
# 329/329 [==============================] - 40s 122ms/step - loss: 0.5131 - accuracy: 0.9861 - val_loss: 1.7752 - val_accuracy: 0.9689 - lr: 0.0020
# Epoch 8/30
# 329/329 [==============================] - ETA: 0s - loss: 0.3962 - accuracy: 0.9889
# Epoch 8: val_loss did not improve from 1.50389
# 329/329 [==============================] - 41s 125ms/step - loss: 0.3962 - accuracy: 0.9889 - val_loss: 1.6590 - val_accuracy: 0.9738 - lr: 0.0020
# Epoch 9/30
# 329/329 [==============================] - ETA: 0s - loss: 0.3453 - accuracy: 0.9904
# Epoch 9: val_loss did not improve from 1.50389
# 329/329 [==============================] - 41s 125ms/step - loss: 0.3453 - accuracy: 0.9904 - val_loss: 2.3333 - val_accuracy: 0.9662 - lr: 0.0020
# Epoch 10/30
# 329/329 [==============================] - ETA: 0s - loss: 0.3121 - accuracy: 0.9913
# Epoch 10: val_loss did not improve from 1.50389
# 329/329 [==============================] - 40s 120ms/step - loss: 0.3121 - accuracy: 0.9913 - val_loss: 2.9402 - val_accuracy: 0.9578 - lr: 0.0020
# Epoch 11/30
# 329/329 [==============================] - ETA: 0s - loss: 0.4148 - accuracy: 0.9897
# Epoch 11: val_loss did not improve from 1.50389
# 329/329 [==============================] - 40s 121ms/step - loss: 0.4148 - accuracy: 0.9897 - val_loss: 3.0134 - val_accuracy: 0.9591 - lr: 0.0020
# Epoch 12/30
# 329/329 [==============================] - ETA: 0s - loss: 0.5809 - accuracy: 0.9880
# Epoch 12: val_loss did not improve from 1.50389
# 329/329 [==============================] - 42s 127ms/step - loss: 0.5809 - accuracy: 0.9880 - val_loss: 2.1932 - val_accuracy: 0.9756 - lr: 0.0020
# Epoch 13/30
# 329/329 [==============================] - ETA: 0s - loss: 0.3576 - accuracy: 0.9922
# Epoch 13: val_loss did not improve from 1.50389
# 329/329 [==============================] - 41s 124ms/step - loss: 0.3576 - accuracy: 0.9922 - val_loss: 3.7542 - val_accuracy: 0.9578 - lr: 0.0020
# Epoch 14/30
# 329/329 [==============================] - ETA: 0s - loss: 0.4363 - accuracy: 0.9907
# Epoch 14: val_loss did not improve from 1.50389
# 329/329 [==============================] - 41s 123ms/step - loss: 0.4363 - accuracy: 0.9907 - val_loss: 3.2243 - val_accuracy: 0.9716 - lr: 0.0020
# Epoch 15/30
# 329/329 [==============================] - ETA: 0s - loss: 0.3034 - accuracy: 0.9943
# Epoch 15: val_loss did not improve from 1.50389
# 329/329 [==============================] - 41s 126ms/step - loss: 0.3034 - accuracy: 0.9943 - val_loss: 2.5266 - val_accuracy: 0.9676 - lr: 0.0020
# Epoch 16/30
# 329/329 [==============================] - ETA: 0s - loss: 0.3744 - accuracy: 0.9925
# Epoch 16: val_loss did not improve from 1.50389
# 329/329 [==============================] - 40s 123ms/step - loss: 0.3744 - accuracy: 0.9925 - val_loss: 3.5460 - val_accuracy: 0.9644 - lr: 0.0020
# Epoch 17/30
# 329/329 [==============================] - ETA: 0s - loss: 0.3566 - accuracy: 0.9939
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 17: val_loss did not improve from 1.50389
# 329/329 [==============================] - 43s 132ms/step - loss: 0.3566 - accuracy: 0.9939 - val_loss: 3.8144 - val_accuracy: 0.9636 - lr: 0.0020
# Epoch 18/30
# 329/329 [==============================] - ETA: 0s - loss: 0.1480 - accuracy: 0.9972
# Epoch 18: val_loss did not improve from 1.50389
# 329/329 [==============================] - 40s 120ms/step - loss: 0.1480 - accuracy: 0.9972 - val_loss: 2.4758 - val_accuracy: 0.9769 - lr: 0.0010
# Epoch 19/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0316 - accuracy: 0.9991
# Epoch 19: val_loss did not improve from 1.50389
# 329/329 [==============================] - 40s 121ms/step - loss: 0.0316 - accuracy: 0.9991 - val_loss: 2.8347 - val_accuracy: 0.9680 - lr: 0.0010
# Epoch 20/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0354 - accuracy: 0.9985
# Epoch 20: val_loss did not improve from 1.50389
# 329/329 [==============================] - 42s 127ms/step - loss: 0.0354 - accuracy: 0.9985 - val_loss: 2.1580 - val_accuracy: 0.9769 - lr: 0.0010
# Epoch 21/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9990
# Epoch 21: val_loss did not improve from 1.50389
# 329/329 [==============================] - 45s 135ms/step - loss: 0.0277 - accuracy: 0.9990 - val_loss: 2.1214 - val_accuracy: 0.9782 - lr: 0.0010
# Epoch 22/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0926 - accuracy: 0.9973
# Epoch 22: val_loss did not improve from 1.50389
# 329/329 [==============================] - 46s 140ms/step - loss: 0.0926 - accuracy: 0.9973 - val_loss: 2.4949 - val_accuracy: 0.9769 - lr: 0.0010
# Epoch 23/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0629 - accuracy: 0.9978
# Epoch 23: val_loss did not improve from 1.50389
# 329/329 [==============================] - 41s 126ms/step - loss: 0.0629 - accuracy: 0.9978 - val_loss: 2.9315 - val_accuracy: 0.9698 - lr: 0.0010
# Epoch 24/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9978
# Epoch 24: val_loss did not improve from 1.50389
# 329/329 [==============================] - 42s 126ms/step - loss: 0.0641 - accuracy: 0.9978 - val_loss: 3.7184 - val_accuracy: 0.9649 - lr: 0.0010
# Epoch 25/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0843 - accuracy: 0.9981
# Epoch 25: val_loss did not improve from 1.50389
# 329/329 [==============================] - 40s 121ms/step - loss: 0.0843 - accuracy: 0.9981 - val_loss: 2.9299 - val_accuracy: 0.9751 - lr: 0.0010
# Epoch 26/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0740 - accuracy: 0.9974
# Epoch 26: val_loss did not improve from 1.50389
# 329/329 [==============================] - 41s 125ms/step - loss: 0.0740 - accuracy: 0.9974 - val_loss: 4.1319 - val_accuracy: 0.9676 - lr: 0.0010
# Epoch 27/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0622 - accuracy: 0.9986
# Epoch 27: val_loss did not improve from 1.50389
# 329/329 [==============================] - 48s 146ms/step - loss: 0.0622 - accuracy: 0.9986 - val_loss: 2.2607 - val_accuracy: 0.9756 - lr: 0.0010
# Epoch 28/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0612 - accuracy: 0.9979
# Epoch 28: val_loss did not improve from 1.50389
# 329/329 [==============================] - 48s 147ms/step - loss: 0.0612 - accuracy: 0.9979 - val_loss: 3.0754 - val_accuracy: 0.9671 - lr: 0.0010
# Epoch 29/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0426 - accuracy: 0.9988
# Epoch 29: val_loss did not improve from 1.50389
# 329/329 [==============================] - 43s 129ms/step - loss: 0.0426 - accuracy: 0.9988 - val_loss: 2.5858 - val_accuracy: 0.9698 - lr: 0.0010
# Epoch 30/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0932 - accuracy: 0.9975
# Epoch 30: val_loss did not improve from 1.50389
# 329/329 [==============================] - 42s 128ms/step - loss: 0.0932 - accuracy: 0.9975 - val_loss: 2.7740 - val_accuracy: 0.9738 - lr: 0.0010
# 71/71 [==============================] - 10s 135ms/step - loss: 4.5363 - accuracy: 0.9684
# Accuracy on the Test Set = 96.84 %
# Model Saved!
# True :  [0 0 0 ... 2 2 2]
# 71/71 [==============================] - 8s 108ms/step
# Predicted :  [0 0 0 ... 2 2 2]
# ACCURACY=0.9684444444444444
# RECALL=0.9684444444444444
# precision=0.9688725780364567
# F1 Score0.9683784986919409
# ######################################################
# RESULTS FORDenseNet201
# Epoch 1/30
# 329/329 [==============================] - ETA: 0s - loss: 8.1771 - accuracy: 0.8108
# Epoch 1: val_loss improved from inf to 1.72649, saving model to Brain CancerDenseNet201.h5
# 329/329 [==============================] - 59s 144ms/step - loss: 8.1771 - accuracy: 0.8108 - val_loss: 1.7265 - val_accuracy: 0.9178 - lr: 0.0020
# Epoch 2/30
# 329/329 [==============================] - ETA: 0s - loss: 3.2702 - accuracy: 0.8973
# Epoch 2: val_loss did not improve from 1.72649
# 329/329 [==============================] - 42s 128ms/step - loss: 3.2702 - accuracy: 0.8973 - val_loss: 1.7877 - val_accuracy: 0.9320 - lr: 0.0020
# Epoch 3/30
# 329/329 [==============================] - ETA: 0s - loss: 2.2018 - accuracy: 0.9306
# Epoch 3: val_loss did not improve from 1.72649
# 329/329 [==============================] - 42s 127ms/step - loss: 2.2018 - accuracy: 0.9306 - val_loss: 3.2566 - val_accuracy: 0.9124 - lr: 0.0020
# Epoch 4/30
# 329/329 [==============================] - ETA: 0s - loss: 2.0956 - accuracy: 0.9393
# Epoch 4: val_loss did not improve from 1.72649
# 329/329 [==============================] - 43s 131ms/step - loss: 2.0956 - accuracy: 0.9393 - val_loss: 9.1183 - val_accuracy: 0.8404 - lr: 0.0020
# Epoch 5/30
# 329/329 [==============================] - ETA: 0s - loss: 2.1338 - accuracy: 0.9447
# Epoch 5: val_loss improved from 1.72649 to 1.21983, saving model to Brain CancerDenseNet201.h5
# 329/329 [==============================] - 45s 136ms/step - loss: 2.1338 - accuracy: 0.9447 - val_loss: 1.2198 - val_accuracy: 0.9591 - lr: 0.0020
# Epoch 6/30
# 329/329 [==============================] - ETA: 0s - loss: 1.2581 - accuracy: 0.9612
# Epoch 6: val_loss did not improve from 1.21983
# 329/329 [==============================] - 43s 131ms/step - loss: 1.2581 - accuracy: 0.9612 - val_loss: 3.5154 - val_accuracy: 0.9124 - lr: 0.0020
# Epoch 7/30
# 329/329 [==============================] - ETA: 0s - loss: 1.5146 - accuracy: 0.9576
# Epoch 7: val_loss did not improve from 1.21983
# 329/329 [==============================] - 44s 134ms/step - loss: 1.5146 - accuracy: 0.9576 - val_loss: 2.4959 - val_accuracy: 0.9476 - lr: 0.0020
# Epoch 8/30
# 329/329 [==============================] - ETA: 0s - loss: 0.8238 - accuracy: 0.9758
# Epoch 8: val_loss did not improve from 1.21983
# 329/329 [==============================] - 44s 133ms/step - loss: 0.8238 - accuracy: 0.9758 - val_loss: 3.1823 - val_accuracy: 0.9324 - lr: 0.0020
# Epoch 9/30
# 329/329 [==============================] - ETA: 0s - loss: 1.2709 - accuracy: 0.9658
# Epoch 9: val_loss did not improve from 1.21983
# 329/329 [==============================] - 44s 133ms/step - loss: 1.2709 - accuracy: 0.9658 - val_loss: 5.9865 - val_accuracy: 0.9040 - lr: 0.0020
# Epoch 10/30
# 329/329 [==============================] - ETA: 0s - loss: 0.7846 - accuracy: 0.9772
# Epoch 10: val_loss did not improve from 1.21983
# 329/329 [==============================] - 44s 132ms/step - loss: 0.7846 - accuracy: 0.9772 - val_loss: 1.3974 - val_accuracy: 0.9618 - lr: 0.0020
# Epoch 11/30
# 329/329 [==============================] - ETA: 0s - loss: 0.4818 - accuracy: 0.9831
# Epoch 11: val_loss did not improve from 1.21983
# 329/329 [==============================] - 45s 137ms/step - loss: 0.4818 - accuracy: 0.9831 - val_loss: 2.0317 - val_accuracy: 0.9507 - lr: 0.0020
# Epoch 12/30
# 329/329 [==============================] - ETA: 0s - loss: 1.9507 - accuracy: 0.9582
# Epoch 12: val_loss did not improve from 1.21983
# 329/329 [==============================] - 43s 130ms/step - loss: 1.9507 - accuracy: 0.9582 - val_loss: 3.0338 - val_accuracy: 0.9462 - lr: 0.0020
# Epoch 13/30
# 329/329 [==============================] - ETA: 0s - loss: 0.7720 - accuracy: 0.9789
# Epoch 13: val_loss did not improve from 1.21983
# 329/329 [==============================] - 44s 134ms/step - loss: 0.7720 - accuracy: 0.9789 - val_loss: 1.8434 - val_accuracy: 0.9609 - lr: 0.0020
# Epoch 14/30
# 329/329 [==============================] - ETA: 0s - loss: 1.0912 - accuracy: 0.9750
# Epoch 14: val_loss did not improve from 1.21983
# 329/329 [==============================] - 44s 133ms/step - loss: 1.0912 - accuracy: 0.9750 - val_loss: 1.9399 - val_accuracy: 0.9631 - lr: 0.0020
# Epoch 15/30
# 329/329 [==============================] - ETA: 0s - loss: 0.5490 - accuracy: 0.9847
# Epoch 15: val_loss did not improve from 1.21983
# 329/329 [==============================] - 42s 127ms/step - loss: 0.5490 - accuracy: 0.9847 - val_loss: 2.0747 - val_accuracy: 0.9649 - lr: 0.0020
# Epoch 16/30
# 329/329 [==============================] - ETA: 0s - loss: 1.7594 - accuracy: 0.9710
# Epoch 16: val_loss did not improve from 1.21983
# 329/329 [==============================] - 42s 127ms/step - loss: 1.7594 - accuracy: 0.9710 - val_loss: 3.5293 - val_accuracy: 0.9467 - lr: 0.0020
# Epoch 17/30
# 329/329 [==============================] - ETA: 0s - loss: 0.7638 - accuracy: 0.9842
# Epoch 17: val_loss did not improve from 1.21983
# 329/329 [==============================] - 43s 131ms/step - loss: 0.7638 - accuracy: 0.9842 - val_loss: 5.1210 - val_accuracy: 0.9311 - lr: 0.0020
# Epoch 18/30
# 329/329 [==============================] - ETA: 0s - loss: 0.5249 - accuracy: 0.9860
# Epoch 18: val_loss did not improve from 1.21983
# 329/329 [==============================] - 41s 123ms/step - loss: 0.5249 - accuracy: 0.9860 - val_loss: 1.9923 - val_accuracy: 0.9649 - lr: 0.0020
# Epoch 19/30
# 329/329 [==============================] - ETA: 0s - loss: 0.6010 - accuracy: 0.9860
# Epoch 19: val_loss did not improve from 1.21983
# 329/329 [==============================] - 43s 129ms/step - loss: 0.6010 - accuracy: 0.9860 - val_loss: 2.9857 - val_accuracy: 0.9556 - lr: 0.0020
# Epoch 20/30
# 329/329 [==============================] - ETA: 0s - loss: 0.8610 - accuracy: 0.9833
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 20: val_loss did not improve from 1.21983
# 329/329 [==============================] - 45s 135ms/step - loss: 0.8610 - accuracy: 0.9833 - val_loss: 3.4011 - val_accuracy: 0.9547 - lr: 0.0020
# Epoch 21/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0910 - accuracy: 0.9966
# Epoch 21: val_loss did not improve from 1.21983
# 329/329 [==============================] - 47s 144ms/step - loss: 0.0910 - accuracy: 0.9966 - val_loss: 2.3331 - val_accuracy: 0.9653 - lr: 0.0010
# Epoch 22/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0563 - accuracy: 0.9971
# Epoch 22: val_loss did not improve from 1.21983
# 329/329 [==============================] - 49s 150ms/step - loss: 0.0563 - accuracy: 0.9971 - val_loss: 1.7728 - val_accuracy: 0.9680 - lr: 0.0010
# Epoch 23/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9994
# Epoch 23: val_loss did not improve from 1.21983
# 329/329 [==============================] - 45s 137ms/step - loss: 0.0142 - accuracy: 0.9994 - val_loss: 2.0217 - val_accuracy: 0.9627 - lr: 0.0010
# Epoch 24/30
# 329/329 [==============================] - ETA: 0s - loss: 0.1187 - accuracy: 0.9965
# Epoch 24: val_loss did not improve from 1.21983
# 329/329 [==============================] - 45s 135ms/step - loss: 0.1187 - accuracy: 0.9965 - val_loss: 2.3448 - val_accuracy: 0.9644 - lr: 0.0010
# Epoch 25/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0966 - accuracy: 0.9966
# Epoch 25: val_loss did not improve from 1.21983
# 329/329 [==============================] - 43s 132ms/step - loss: 0.0966 - accuracy: 0.9966 - val_loss: 2.1081 - val_accuracy: 0.9667 - lr: 0.0010
# Epoch 26/30
# 329/329 [==============================] - ETA: 0s - loss: 0.1564 - accuracy: 0.9956
# Epoch 26: val_loss did not improve from 1.21983
# 329/329 [==============================] - 41s 124ms/step - loss: 0.1564 - accuracy: 0.9956 - val_loss: 2.3113 - val_accuracy: 0.9604 - lr: 0.0010
# Epoch 27/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0673 - accuracy: 0.9977
# Epoch 27: val_loss did not improve from 1.21983
# 329/329 [==============================] - 42s 128ms/step - loss: 0.0673 - accuracy: 0.9977 - val_loss: 4.0933 - val_accuracy: 0.9449 - lr: 0.0010
# Epoch 28/30
# 329/329 [==============================] - ETA: 0s - loss: 0.8585 - accuracy: 0.9827
# Epoch 28: val_loss did not improve from 1.21983
# 329/329 [==============================] - 41s 123ms/step - loss: 0.8585 - accuracy: 0.9827 - val_loss: 2.0940 - val_accuracy: 0.9711 - lr: 0.0010
# Epoch 29/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0986 - accuracy: 0.9970
# Epoch 29: val_loss did not improve from 1.21983
# 329/329 [==============================] - 42s 126ms/step - loss: 0.0986 - accuracy: 0.9970 - val_loss: 1.8233 - val_accuracy: 0.9738 - lr: 0.0010
# Epoch 30/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.9971
# Epoch 30: val_loss did not improve from 1.21983
# 329/329 [==============================] - 42s 128ms/step - loss: 0.0610 - accuracy: 0.9971 - val_loss: 1.2427 - val_accuracy: 0.9778 - lr: 0.0010
# 71/71 [==============================] - 10s 143ms/step - loss: 2.7726 - accuracy: 0.9596
# Accuracy on the Test Set = 95.96 %
# Model Saved!
# True :  [0 0 0 ... 2 2 2]
# 71/71 [==============================] - 11s 99ms/step
# Predicted :  [0 0 0 ... 2 2 2]
# ACCURACY=0.9595555555555556
# RECALL=0.9595555555555556
# precision=0.959682605299268
# F1 Score0.9595922637062334
# ######################################################
# RESULTS FORMobileNetV3
# Epoch 1/30
# 329/329 [==============================] - ETA: 0s - loss: 1.4877 - accuracy: 0.8827
# Epoch 1: val_loss improved from inf to 1.17888, saving model to Brain CancerMobileNetV3.h5
# 329/329 [==============================] - 41s 112ms/step - loss: 1.4877 - accuracy: 0.8827 - val_loss: 1.1789 - val_accuracy: 0.9036 - lr: 0.0020
# Epoch 2/30
# 329/329 [==============================] - ETA: 0s - loss: 0.5338 - accuracy: 0.9563
# Epoch 2: val_loss improved from 1.17888 to 0.81663, saving model to Brain CancerMobileNetV3.h5
# 329/329 [==============================] - 36s 109ms/step - loss: 0.5338 - accuracy: 0.9563 - val_loss: 0.8166 - val_accuracy: 0.9449 - lr: 0.0020
# Epoch 3/30
# 329/329 [==============================] - ETA: 0s - loss: 0.3878 - accuracy: 0.9683
# Epoch 3: val_loss did not improve from 0.81663
# 329/329 [==============================] - 39s 119ms/step - loss: 0.3878 - accuracy: 0.9683 - val_loss: 1.1263 - val_accuracy: 0.9431 - lr: 0.0020
# Epoch 4/30
# 329/329 [==============================] - ETA: 0s - loss: 0.2196 - accuracy: 0.9818
# Epoch 4: val_loss improved from 0.81663 to 0.63292, saving model to Brain CancerMobileNetV3.h5
# 329/329 [==============================] - 38s 115ms/step - loss: 0.2196 - accuracy: 0.9818 - val_loss: 0.6329 - val_accuracy: 0.9631 - lr: 0.0020
# Epoch 5/30
# 329/329 [==============================] - ETA: 0s - loss: 0.1759 - accuracy: 0.9850
# Epoch 5: val_loss improved from 0.63292 to 0.60803, saving model to Brain CancerMobileNetV3.h5
# 329/329 [==============================] - 38s 115ms/step - loss: 0.1759 - accuracy: 0.9850 - val_loss: 0.6080 - val_accuracy: 0.9684 - lr: 0.0020
# Epoch 6/30
# 329/329 [==============================] - ETA: 0s - loss: 0.2004 - accuracy: 0.9847
# Epoch 6: val_loss did not improve from 0.60803
# 329/329 [==============================] - 38s 116ms/step - loss: 0.2004 - accuracy: 0.9847 - val_loss: 1.6634 - val_accuracy: 0.9271 - lr: 0.0020
# Epoch 7/30
# 329/329 [==============================] - ETA: 0s - loss: 0.2761 - accuracy: 0.9818
# Epoch 7: val_loss did not improve from 0.60803
# 329/329 [==============================] - 37s 112ms/step - loss: 0.2761 - accuracy: 0.9818 - val_loss: 0.6744 - val_accuracy: 0.9631 - lr: 0.0020
# Epoch 8/30
# 329/329 [==============================] - ETA: 0s - loss: 0.1278 - accuracy: 0.9907
# Epoch 8: val_loss did not improve from 0.60803
# 329/329 [==============================] - 35s 106ms/step - loss: 0.1278 - accuracy: 0.9907 - val_loss: 0.6792 - val_accuracy: 0.9644 - lr: 0.0020
# Epoch 9/30
# 329/329 [==============================] - ETA: 0s - loss: 0.2354 - accuracy: 0.9863
# Epoch 9: val_loss did not improve from 0.60803
# 329/329 [==============================] - 36s 110ms/step - loss: 0.2354 - accuracy: 0.9863 - val_loss: 0.6267 - val_accuracy: 0.9680 - lr: 0.0020
# Epoch 10/30
# 329/329 [==============================] - ETA: 0s - loss: 0.1706 - accuracy: 0.9887
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 10: val_loss did not improve from 0.60803
# 329/329 [==============================] - 36s 110ms/step - loss: 0.1706 - accuracy: 0.9887 - val_loss: 1.6055 - val_accuracy: 0.9418 - lr: 0.0020
# Epoch 11/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0624 - accuracy: 0.9961
# Epoch 11: val_loss did not improve from 0.60803
# 329/329 [==============================] - 36s 110ms/step - loss: 0.0624 - accuracy: 0.9961 - val_loss: 0.6146 - val_accuracy: 0.9756 - lr: 0.0010
# Epoch 12/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9991
# Epoch 12: val_loss did not improve from 0.60803
# 329/329 [==============================] - 37s 113ms/step - loss: 0.0056 - accuracy: 0.9991 - val_loss: 0.7282 - val_accuracy: 0.9707 - lr: 0.0010
# Epoch 13/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9989
# Epoch 13: val_loss did not improve from 0.60803
# 329/329 [==============================] - 35s 106ms/step - loss: 0.0096 - accuracy: 0.9989 - val_loss: 0.8808 - val_accuracy: 0.9676 - lr: 0.0010
# Epoch 14/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9981
# Epoch 14: val_loss did not improve from 0.60803
# 329/329 [==============================] - 36s 109ms/step - loss: 0.0230 - accuracy: 0.9981 - val_loss: 0.7283 - val_accuracy: 0.9742 - lr: 0.0010
# Epoch 15/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0272 - accuracy: 0.9976
# Epoch 15: val_loss did not improve from 0.60803
# 329/329 [==============================] - 36s 110ms/step - loss: 0.0272 - accuracy: 0.9976 - val_loss: 0.7225 - val_accuracy: 0.9724 - lr: 0.0010
# Epoch 16/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.9970
# Epoch 16: val_loss did not improve from 0.60803
# 329/329 [==============================] - 36s 108ms/step - loss: 0.0299 - accuracy: 0.9970 - val_loss: 0.6442 - val_accuracy: 0.9724 - lr: 0.0010
# Epoch 17/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9967
# Epoch 17: val_loss did not improve from 0.60803
# 329/329 [==============================] - 37s 112ms/step - loss: 0.0397 - accuracy: 0.9967 - val_loss: 0.7845 - val_accuracy: 0.9716 - lr: 0.0010
# Epoch 18/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0661 - accuracy: 0.9956
# Epoch 18: val_loss did not improve from 0.60803
# 329/329 [==============================] - 37s 113ms/step - loss: 0.0661 - accuracy: 0.9956 - val_loss: 1.6305 - val_accuracy: 0.9498 - lr: 0.0010
# Epoch 19/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9969
# Epoch 19: val_loss did not improve from 0.60803
# 329/329 [==============================] - 34s 103ms/step - loss: 0.0360 - accuracy: 0.9969 - val_loss: 1.0526 - val_accuracy: 0.9627 - lr: 0.0010
# Epoch 20/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9965
# Epoch 20: val_loss did not improve from 0.60803
# 329/329 [==============================] - 36s 108ms/step - loss: 0.0405 - accuracy: 0.9965 - val_loss: 0.8366 - val_accuracy: 0.9711 - lr: 0.0010
# Epoch 21/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9976
# Epoch 21: val_loss did not improve from 0.60803
# 329/329 [==============================] - 35s 107ms/step - loss: 0.0331 - accuracy: 0.9976 - val_loss: 0.9357 - val_accuracy: 0.9733 - lr: 0.0010
# Epoch 22/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0500 - accuracy: 0.9963
# Epoch 22: val_loss did not improve from 0.60803
# 329/329 [==============================] - 37s 114ms/step - loss: 0.0500 - accuracy: 0.9963 - val_loss: 0.8059 - val_accuracy: 0.9733 - lr: 0.0010
# Epoch 23/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9969
# Epoch 23: val_loss did not improve from 0.60803
# 329/329 [==============================] - 35s 107ms/step - loss: 0.0405 - accuracy: 0.9969 - val_loss: 0.7580 - val_accuracy: 0.9764 - lr: 0.0010
# Epoch 24/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9981
# Epoch 24: val_loss did not improve from 0.60803
# 329/329 [==============================] - 53s 161ms/step - loss: 0.0224 - accuracy: 0.9981 - val_loss: 0.7892 - val_accuracy: 0.9733 - lr: 0.0010
# Epoch 25/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9991
# Epoch 25: val_loss did not improve from 0.60803
# 329/329 [==============================] - 35s 105ms/step - loss: 0.0099 - accuracy: 0.9991 - val_loss: 1.0105 - val_accuracy: 0.9676 - lr: 0.0010
# Epoch 26/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9980
# Epoch 26: val_loss did not improve from 0.60803
# 329/329 [==============================] - 36s 108ms/step - loss: 0.0195 - accuracy: 0.9980 - val_loss: 1.1137 - val_accuracy: 0.9667 - lr: 0.0010
# Epoch 27/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0537 - accuracy: 0.9967
# Epoch 27: val_loss did not improve from 0.60803
# 329/329 [==============================] - 39s 118ms/step - loss: 0.0537 - accuracy: 0.9967 - val_loss: 0.9501 - val_accuracy: 0.9689 - lr: 0.0010
# Epoch 28/30
# 329/329 [==============================] - ETA: 0s - loss: 0.1126 - accuracy: 0.9930
# Epoch 28: val_loss did not improve from 0.60803
# 329/329 [==============================] - 39s 117ms/step - loss: 0.1126 - accuracy: 0.9930 - val_loss: 1.1569 - val_accuracy: 0.9689 - lr: 0.0010
# Epoch 29/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9977
# Epoch 29: val_loss did not improve from 0.60803
# 329/329 [==============================] - 39s 119ms/step - loss: 0.0314 - accuracy: 0.9977 - val_loss: 0.9190 - val_accuracy: 0.9707 - lr: 0.0010
# Epoch 30/30
# 329/329 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9951
# Epoch 30: val_loss did not improve from 0.60803
# 329/329 [==============================] - 46s 139ms/step - loss: 0.0746 - accuracy: 0.9951 - val_loss: 1.0510 - val_accuracy: 0.9724 - lr: 0.0010
# 71/71 [==============================] - 8s 115ms/step - loss: 1.1386 - accuracy: 0.9698
# Accuracy on the Test Set = 96.98 %
# Model Saved!
# True :  [0 0 0 ... 2 2 2]
# 71/71 [==============================] - 10s 134ms/step
# Predicted :  [0 0 0 ... 2 2 2]
# ACCURACY=0.9697777777777777
# RECALL=0.9697777777777777
# precision=0.9699118252039262
# F1 Score0.9697824194666587
# ######################################################
# RESULTS FORResNet50V2
# Epoch 1/30
# 329/329 [==============================] - ETA: 0s - loss: 158.7659 - accuracy: 0.7288
# Epoch 1: val_loss improved from inf to 93.02885, saving model to Brain CancerResNet50V2.h5
# 329/329 [==============================] - 54s 156ms/step - loss: 158.7659 - accuracy: 0.7288 - val_loss: 93.0288 - val_accuracy: 0.8000 - lr: 0.0020
# Epoch 2/30
# 329/329 [==============================] - ETA: 0s - loss: 77.6737 - accuracy: 0.8302
# Epoch 2: val_loss improved from 93.02885 to 89.76596, saving model to Brain CancerResNet50V2.h5
# 329/329 [==============================] - 43s 132ms/step - loss: 77.6737 - accuracy: 0.8302 - val_loss: 89.7660 - val_accuracy: 0.8333 - lr: 0.0020
# Epoch 3/30
# 329/329 [==============================] - ETA: 0s - loss: 61.0272 - accuracy: 0.8643
# Epoch 3: val_loss improved from 89.76596 to 61.23159, saving model to Brain CancerResNet50V2.h5
# 329/329 [==============================] - 46s 141ms/step - loss: 61.0272 - accuracy: 0.8643 - val_loss: 61.2316 - val_accuracy: 0.8578 - lr: 0.0020
# Epoch 4/30
# 329/329 [==============================] - ETA: 0s - loss: 56.8552 - accuracy: 0.8770
# Epoch 4: val_loss did not improve from 61.23159
# 329/329 [==============================] - 39s 117ms/step - loss: 56.8552 - accuracy: 0.8770 - val_loss: 73.5835 - val_accuracy: 0.8644 - lr: 0.0020
# Epoch 5/30
# 329/329 [==============================] - ETA: 0s - loss: 55.3666 - accuracy: 0.8863
# Epoch 5: val_loss did not improve from 61.23159
# 329/329 [==============================] - 39s 119ms/step - loss: 55.3666 - accuracy: 0.8863 - val_loss: 94.2288 - val_accuracy: 0.8404 - lr: 0.0020
# Epoch 6/30
# 329/329 [==============================] - ETA: 0s - loss: 64.5756 - accuracy: 0.8850
# Epoch 6: val_loss did not improve from 61.23159
# 329/329 [==============================] - 38s 116ms/step - loss: 64.5756 - accuracy: 0.8850 - val_loss: 68.9624 - val_accuracy: 0.8818 - lr: 0.0020
# Epoch 7/30
# 329/329 [==============================] - ETA: 0s - loss: 50.5144 - accuracy: 0.9055
# Epoch 7: val_loss did not improve from 61.23159
# 329/329 [==============================] - 40s 122ms/step - loss: 50.5144 - accuracy: 0.9055 - val_loss: 100.6593 - val_accuracy: 0.8693 - lr: 0.0020
# Epoch 8/30
# 329/329 [==============================] - ETA: 0s - loss: 26.7808 - accuracy: 0.9382
# Epoch 8: val_loss did not improve from 61.23159
# 329/329 [==============================] - 42s 127ms/step - loss: 26.7808 - accuracy: 0.9382 - val_loss: 67.4244 - val_accuracy: 0.8809 - lr: 0.0020
# Epoch 9/30
# 329/329 [==============================] - ETA: 0s - loss: 34.4012 - accuracy: 0.9278
# Epoch 9: val_loss did not improve from 61.23159
# 329/329 [==============================] - 37s 114ms/step - loss: 34.4012 - accuracy: 0.9278 - val_loss: 98.3729 - val_accuracy: 0.8618 - lr: 0.0020
# Epoch 10/30
# 329/329 [==============================] - ETA: 0s - loss: 64.2772 - accuracy: 0.9030
# Epoch 10: val_loss did not improve from 61.23159
# 329/329 [==============================] - 38s 114ms/step - loss: 64.2772 - accuracy: 0.9030 - val_loss: 136.8259 - val_accuracy: 0.8507 - lr: 0.0020
# Epoch 11/30
# 329/329 [==============================] - ETA: 0s - loss: 34.8575 - accuracy: 0.9381
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 11: val_loss did not improve from 61.23159
# 329/329 [==============================] - 38s 117ms/step - loss: 34.8575 - accuracy: 0.9381 - val_loss: 173.1348 - val_accuracy: 0.8231 - lr: 0.0020
# Epoch 12/30
# 329/329 [==============================] - ETA: 0s - loss: 8.4233 - accuracy: 0.9750
# Epoch 12: val_loss did not improve from 61.23159
# 329/329 [==============================] - 49s 148ms/step - loss: 8.4233 - accuracy: 0.9750 - val_loss: 63.2438 - val_accuracy: 0.9004 - lr: 0.0010
# Epoch 13/30
# 329/329 [==============================] - ETA: 0s - loss: 5.6297 - accuracy: 0.9803
# Epoch 13: val_loss improved from 61.23159 to 53.70094, saving model to Brain CancerResNet50V2.h5
# 329/329 [==============================] - 49s 148ms/step - loss: 5.6297 - accuracy: 0.9803 - val_loss: 53.7009 - val_accuracy: 0.9053 - lr: 0.0010
# Epoch 14/30
# 329/329 [==============================] - ETA: 0s - loss: 5.6544 - accuracy: 0.9820
# Epoch 14: val_loss did not improve from 53.70094
# 329/329 [==============================] - 45s 137ms/step - loss: 5.6544 - accuracy: 0.9820 - val_loss: 57.2743 - val_accuracy: 0.9058 - lr: 0.0010
# Epoch 15/30
# 329/329 [==============================] - ETA: 0s - loss: 9.7003 - accuracy: 0.9722
# Epoch 15: val_loss did not improve from 53.70094
# 329/329 [==============================] - 44s 134ms/step - loss: 9.7003 - accuracy: 0.9722 - val_loss: 68.2209 - val_accuracy: 0.8978 - lr: 0.0010
# Epoch 16/30
# 329/329 [==============================] - ETA: 0s - loss: 4.4446 - accuracy: 0.9834
# Epoch 16: val_loss did not improve from 53.70094
# 329/329 [==============================] - 45s 135ms/step - loss: 4.4446 - accuracy: 0.9834 - val_loss: 69.4961 - val_accuracy: 0.8929 - lr: 0.0010
# Epoch 17/30
# 329/329 [==============================] - ETA: 0s - loss: 10.2882 - accuracy: 0.9731
# Epoch 17: val_loss did not improve from 53.70094
# 329/329 [==============================] - 49s 148ms/step - loss: 10.2882 - accuracy: 0.9731 - val_loss: 75.3062 - val_accuracy: 0.8884 - lr: 0.0010
# Epoch 18/30
# 329/329 [==============================] - ETA: 0s - loss: 9.1322 - accuracy: 0.9749
# Epoch 18: val_loss did not improve from 53.70094
# 329/329 [==============================] - 46s 140ms/step - loss: 9.1322 - accuracy: 0.9749 - val_loss: 96.0523 - val_accuracy: 0.8764 - lr: 0.0010
# Epoch 19/30
# 329/329 [==============================] - ETA: 0s - loss: 10.2664 - accuracy: 0.9717
# Epoch 19: val_loss did not improve from 53.70094
# 329/329 [==============================] - 48s 145ms/step - loss: 10.2664 - accuracy: 0.9717 - val_loss: 74.1238 - val_accuracy: 0.8978 - lr: 0.0010
# Epoch 20/30
# 329/329 [==============================] - ETA: 0s - loss: 8.0759 - accuracy: 0.9769
# Epoch 20: val_loss did not improve from 53.70094
# 329/329 [==============================] - 47s 142ms/step - loss: 8.0759 - accuracy: 0.9769 - val_loss: 84.1952 - val_accuracy: 0.8898 - lr: 0.0010
# Epoch 21/30
# 329/329 [==============================] - ETA: 0s - loss: 8.4810 - accuracy: 0.9750
# Epoch 21: val_loss did not improve from 53.70094
# 329/329 [==============================] - 39s 120ms/step - loss: 8.4810 - accuracy: 0.9750 - val_loss: 70.3226 - val_accuracy: 0.8947 - lr: 0.0010
# Epoch 22/30
# 329/329 [==============================] - ETA: 0s - loss: 14.0842 - accuracy: 0.9637
# Epoch 22: val_loss did not improve from 53.70094
# 329/329 [==============================] - 39s 120ms/step - loss: 14.0842 - accuracy: 0.9637 - val_loss: 86.9661 - val_accuracy: 0.8898 - lr: 0.0010
# Epoch 23/30
# 329/329 [==============================] - ETA: 0s - loss: 6.4232 - accuracy: 0.9821
# Epoch 23: val_loss did not improve from 53.70094
# 329/329 [==============================] - 39s 119ms/step - loss: 6.4232 - accuracy: 0.9821 - val_loss: 101.9290 - val_accuracy: 0.8787 - lr: 0.0010
# Epoch 24/30
# 329/329 [==============================] - ETA: 0s - loss: 20.0397 - accuracy: 0.9600
# Epoch 24: val_loss did not improve from 53.70094
# 329/329 [==============================] - 39s 117ms/step - loss: 20.0397 - accuracy: 0.9600 - val_loss: 66.9368 - val_accuracy: 0.9049 - lr: 0.0010
# Epoch 25/30
# 329/329 [==============================] - ETA: 0s - loss: 2.9289 - accuracy: 0.9890
# Epoch 25: val_loss did not improve from 53.70094
# 329/329 [==============================] - 38s 117ms/step - loss: 2.9289 - accuracy: 0.9890 - val_loss: 69.8566 - val_accuracy: 0.8996 - lr: 0.0010
# Epoch 26/30
# 329/329 [==============================] - ETA: 0s - loss: 6.9081 - accuracy: 0.9795
# Epoch 26: val_loss did not improve from 53.70094
# 329/329 [==============================] - 37s 112ms/step - loss: 6.9081 - accuracy: 0.9795 - val_loss: 76.7275 - val_accuracy: 0.8947 - lr: 0.0010
# Epoch 27/30
# 329/329 [==============================] - ETA: 0s - loss: 6.5383 - accuracy: 0.9796
# Epoch 27: val_loss did not improve from 53.70094
# 329/329 [==============================] - 39s 118ms/step - loss: 6.5383 - accuracy: 0.9796 - val_loss: 79.7507 - val_accuracy: 0.8947 - lr: 0.0010
# Epoch 28/30
# 329/329 [==============================] - ETA: 0s - loss: 8.1134 - accuracy: 0.9787
# Epoch 28: val_loss did not improve from 53.70094
# 329/329 [==============================] - 40s 121ms/step - loss: 8.1134 - accuracy: 0.9787 - val_loss: 104.6989 - val_accuracy: 0.8764 - lr: 0.0010
# Epoch 29/30
# 329/329 [==============================] - ETA: 0s - loss: 5.4028 - accuracy: 0.9832
# Epoch 29: val_loss did not improve from 53.70094
# 329/329 [==============================] - 40s 122ms/step - loss: 5.4028 - accuracy: 0.9832 - val_loss: 70.0884 - val_accuracy: 0.9018 - lr: 0.0010
# Epoch 30/30
# 329/329 [==============================] - ETA: 0s - loss: 4.1401 - accuracy: 0.9864
# Epoch 30: val_loss did not improve from 53.70094
# 329/329 [==============================] - 41s 126ms/step - loss: 4.1401 - accuracy: 0.9864 - val_loss: 112.6004 - val_accuracy: 0.8747 - lr: 0.0010
# 71/71 [==============================] - 7s 94ms/step - loss: 108.1051 - accuracy: 0.8742
# Accuracy on the Test Set = 87.42 %
# Model Saved!
# True :  [0 0 0 ... 2 2 2]
# 71/71 [==============================] - 8s 93ms/step
# Predicted :  [0 0 0 ... 1 2 2]
# ACCURACY=0.8742222222222222
# RECALL=0.8742222222222222
# precision=0.8893087706148176
# F1 Score0.8757004946044663
# ######################################################
# RESULTS FOR ENSEMBLE
# True :  [0 0 0 ... 2 2 2]
# 71/71 [==============================] - 8s 106ms/step
# 71/71 [==============================] - 8s 114ms/step
# 71/71 [==============================] - 6s 88ms/step
# 71/71 [==============================] - 7s 95ms/step
# Predicted :  [0 0 0 ... 2 2 2]
# ACCURACY=0.9808888888888889
# RECALL=0.9808888888888889
# precision=0.980974081159352
# F1 Score0.9808954375713036
